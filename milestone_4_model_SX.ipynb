# %%
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cmx
import matplotlib.colors as colors
import pandas as pd
import math
from sklearn.linear_model import Lasso as Lasso_Reg
from sklearn import linear_model
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.cross_validation import KFold
from sklearn.cross_validation import cross_val_score as val_score
from sklearn.linear_model import LinearRegression as LinReg
from sklearn.linear_model import LogisticRegression as LogReg
from sklearn.decomposition import PCA
from sklearn.cross_validation import train_test_split as sk_split
import statsmodels.api as sm

# %matplotlib inline

# %%
#read in crops
allcrops_2000 = pd.read_csv('datasets/allcrops_2000.csv')
# names of all the crops
crop_names = allcrops_2000['ItemName'].unique()

# remove nan
crop_names = crop_names[:-1]
# list to put our separated crop dataframes
all_crop_dfs = []

# find each crop-separated df and put it in the list of dataframes
for crop in crop_names:
    crop_df = allcrops_2000[(allcrops_2000['ItemName'] == crop)]
    all_crop_dfs.append(crop_df)

print crop_names
# Out:
# ['Wheat and products' 'Barley and products' 'Maize and products'
#  'Rye and products' 'Oats' 'Cereals, Other' 'Potatoes and products'
#  'Sugar (Raw Equivalent)' 'Sweeteners, Other' 'Pulses, Other and products'
#  'Nuts and products' 'Soyabeans' 'Groundnuts (Shelled Eq)'
#  'Coconuts - Incl Copra' 'Sesame seed' 'Olives (including preserved)'
#  'Oilcrops, Other' 'Soyabean Oil' 'Groundnut Oil' 'Sunflowerseed Oil'
#  'Rape and Mustard Oil' 'Cottonseed Oil' 'Palmkernel Oil' 'Coconut Oil'
#  'Sesameseed Oil' 'Olive Oil' 'Maize Germ Oil' 'Oilcrops Oil, Other'
#  'Tomatoes and products' 'Onions' 'Vegetables, Other' 'Oranges, Mandarines'
#  'Lemons, Limes and products' 'Grapefruit and products' 'Citrus, Other'
#  'Bananas' 'Apples and products' 'Pineapples and products' 'Dates'
#  'Grapes and products (excl wine)' 'Fruits, Other' 'Coffee and products'
#  'Cocoa Beans and products' 'Tea (including mate)' 'Pepper' 'Pimento'
#  'Spices, Other' 'Wine' 'Beer' 'Beverages, Fermented'
#  'Beverages, Alcoholic' 'Infant food' 'Rice (Paddy Equivalent)'
#  'Rice (Milled Equivalent)' 'Roots & Tuber Dry Equiv'
#  'Sugar, Refined Equiv' 'Groundnuts (in Shell Eq)' 'Sugar, Raw Equivalent'
#  'Cereals - Excluding Beer' 'Starchy Roots' 'Sugar & Sweeteners' 'Pulses'
#  'Treenuts' 'Oilcrops' 'Vegetable Oils' 'Vegetables'
#  'Fruits - Excluding Wine' 'Stimulants' 'Spices' 'Alcoholic Beverages'
#  'Miscellaneous' 'Millet and products' 'Palm Oil' 'Cassava and products'
#  'Sweet potatoes' 'Roots, Other' 'Beans' 'Peas' 'Sorghum and products'
#  'Plantains' 'Cloves' 'Yams' 'Sunflower seed' 'Sugar cane'
#  'Sugar non-centrifugal' 'Ricebran Oil' 'Sugar Crops' 'Sugar beet'
#  'Molasses']

# %%
# Do the same as above, but for livestock
livestock_2000 = pd.read_csv('datasets/livestock_2000.csv')
# list of livestock names
livestock_names_all = livestock_2000['ItemName'].unique()
livestock_names_all = livestock_names_all[1:-1]
livestock_names = []
for name in livestock_names_all:
    if name != 'Grand Total':
        livestock_names.append(name)

# list to put our separated dataframes
livestock_dfs = []

# separate dataframe based on itemname
for crop in livestock_names:
    crop_df = livestock_2000[(livestock_2000['ItemName'] == crop)]
    livestock_dfs.append(crop_df)

print livestock_names
print len(livestock_names)
# Out:
# ['Bovine Meat', 'Mutton & Goat Meat', 'Pigmeat', 'Poultry Meat', 'Meat, Other', 'Offals, Edible', 'Fats, Animals, Raw', 'Milk, Whole', 'Butter, Ghee', 'Cheese', 'Cream', 'Eggs', 'Honey', 'Freshwater Fish', 'Demersal Fish', 'Pelagic Fish', 'Marine Fish, Other', 'Crustaceans', 'Cephalopods', 'Molluscs, Other', 'Aquatic Plants', 'Fish, Body Oil', 'Fish, Liver Oil', 'Milk - Excluding Butter', 'Meat', 'Offals', 'Animal fats', 'Fish, Seafood', 'Aquatic Products, Other', 'Animal Products', 'Aquatic Animals, Others', 'Whey', 'Meat Meal', 'Meat, Aquatic Mammals', 'Hides and skins']
# 35

# %%
# read in disease rates
column_headers = ["Country", "Year", "Mortality", "Mortality 2", "Mortality 3"]
diabetes = pd.read_csv('datasets/diabetes.csv', names = column_headers)
cardio = pd.read_csv('datasets/cardiovascular.csv', names = column_headers)
cancer= pd.read_csv('datasets/Cancer.csv', names = column_headers)

# %%
cardio.iloc[3:, 0:3].head(n=5)
#cardio.columns = ['Country', 'Year', 'Mortality']
# Out:
#        Country  Year Mortality
# 3  Afghanistan  2012     511.5
# 4  Afghanistan  2000     542.3
# 5      Albania  2012     436.2
# 6      Albania  2000     560.5
# 7      Algeria  2012     396.6

# %%
cardio_2012 = cardio[(cardio["Year"] == "2012")] 
cardio_2000 = cardio[(cardio["Year"] == "2000")]

# %%
diabetes_2012 = diabetes[(diabetes['Year'] == '2012')] 
diabetes_2000 = diabetes[(diabetes['Year'] == '2000')] 
diabetes_2000
# Out:
#                                                Country  Year Mortality  \
# 4                                          Afghanistan  2000      34.0
# 6                                              Albania  2000       8.3
# 8                                              Algeria  2000      67.2
# 10                                              Angola  2000      35.0
# 12                                           Argentina  2000      19.9
# 14                                             Armenia  2000      32.2
# 16                                           Australia  2000      10.2
# 18                                             Austria  2000      15.5
# 20                                          Azerbaijan  2000      19.6
# 22                                             Bahamas  2000      45.6
# 24                                             Bahrain  2000      75.9
# 26                                          Bangladesh  2000      25.7
# 28                                            Barbados  2000      49.9
# 30                                             Belarus  2000       5.1
# 32                                             Belgium  2000       9.3
# 34                                              Belize  2000      54.0
# 36                                               Benin  2000      50.2
# 38                                              Bhutan  2000      30.0
# 40                    Bolivia (Plurinational State of)  2000      45.9
# 42                              Bosnia and Herzegovina  2000      19.8
# 44                                            Botswana  2000      43.2
# 46                                              Brazil  2000      39.3
# 48                                   Brunei Darussalam  2000      59.6
# 50                                            Bulgaria  2000      14.8
# 52                                        Burkina Faso  2000      58.8
# 54                                             Burundi  2000      32.4
# 56                                       Cote d'Ivoire  2000      42.8
# 58                                          Cabo Verde  2000      23.4
# 60                                            Cambodia  2000      15.9
# 62                                            Cameroon  2000      42.7
# ..                                                 ...   ...       ...
# 288                                              Spain  2000      10.7
# 290                                          Sri Lanka  2000      46.8
# 292                                              Sudan  2000      33.2
# 294                                           Suriname  2000      39.4
# 296                                          Swaziland  2000      80.5
# 298                                             Sweden  2000       8.5
# 300                                        Switzerland  2000      10.2
# 302                               Syrian Arab Republic  2000       9.7
# 304                                         Tajikistan  2000      18.0
# 306                                           Thailand  2000      33.6
# 308          The former Yugoslav republic of Macedonia  2000      24.6
# 310                                        Timor-Leste  2000      32.3
# 312                                               Togo  2000      38.4
# 314                                Trinidad and Tobago  2000     136.8
# 316                                            Tunisia  2000      29.7
# 318                                             Turkey  2000      18.0
# 320                                       Turkmenistan  2000      19.8
# 322                                             Uganda  2000      41.5
# 324                                            Ukraine  2000       5.1
# 326                               United Arab Emirates  2000      33.0
# 328  United Kingdom of Great Britain and Northern I...  2000       5.7
# 330                        United Republic of Tanzania  2000      54.3
# 332                           United States of America  2000      16.7
# 334                                            Uruguay  2000      13.5
# 336                                         Uzbekistan  2000      19.4
# 338                 Venezuela (Bolivarian Republic of)  2000      43.6
# 340                                           Viet Nam  2000      16.0
# 342                                              Yemen  2000      26.2
# 344                                             Zambia  2000      45.1
# 346                                           Zimbabwe  2000      21.6
#
#     Mortality 2 Mortality 3
# 4          35.1        32.8
# 6           8.2         8.3
# 8          62.1        73.4
# 10         36.4        33.2
# 12         16.0        25.2
# 14         33.6        29.2
# 16          8.0        13.0
# 18         12.4        19.3
# 20         21.4        16.6
# 22         41.5        49.9
# 24         72.5        78.8
# 26         23.8        27.4
# 28         48.2        50.9
# 30          5.1         4.9
# 32          8.6         9.8
# 34         65.2        41.5
# 36         50.2        49.7
# 38         32.3        28.1
# 40         49.5        41.2
# 42         23.2        14.7
# 44         53.7        27.7
# 46         42.2        35.4
# 48         64.8        54.2
# 50         14.7        14.6
# 52         67.3        46.0
# 54         28.6        36.8
# 56         46.5        39.3
# 58         22.7        24.3
# 60         18.1        13.2
# 62         43.8        41.1
# ..          ...         ...
# 288        10.1        11.0
# 290        40.2        53.7
# 292        32.7        33.7
# 294        34.4        44.8
# 296       102.4        52.7
# 298         7.0        10.4
# 300         8.9        11.6
# 302        10.4         8.8
# 304        19.0        17.1
# 306        38.5        27.7
# 308        25.9        22.8
# 310        37.9        26.3
# 312        39.2        37.2
# 314       122.0       155.6
# 316        33.5        25.5
# 318        19.2        16.1
# 320        20.6        18.5
# 322        38.2        45.2
# 324         5.0         5.2
# 326        40.8        27.3
# 328         4.8         6.8
# 330        53.2        55.1
# 332        15.1        18.7
# 334        12.0        15.4
# 336        18.4        20.5
# 338        44.8        42.0
# 340        15.4        16.6
# 342        26.5        25.9
# 344        49.7        39.0
# 346        22.2        20.6
#
# [172 rows x 5 columns]

# %%
cancer_2012 = cancer[(cancer['Year'] == ' 2012')] 
cancer_2000 = cancer[(cancer['Year'] == ' 2000')] 
cancer_2012
# Out:
#                                                Country   Year Mortality  \
# 3                                          Afghanistan   2012     123.6
# 5                                              Albania   2012     123.1
# 7                                              Algeria   2012      80.6
# 9                                               Angola   2012      89.6
# 11                                           Argentina   2012     131.5
# 13                                             Armenia   2012     219.6
# 15                                           Australia   2012     111.0
# 17                                             Austria   2012     122.0
# 19                                          Azerbaijan   2012     112.8
# 21                                             Bahamas   2012     103.8
# 23                                             Bahrain   2012      71.3
# 25                                          Bangladesh   2012      87.8
# 27                                            Barbados   2012     140.4
# 29                                             Belarus   2012     117.0
# 31                                             Belgium   2012     130.3
# 33                                              Belize   2012      83.4
# 35                                               Benin   2012      89.6
# 37                                              Bhutan   2012      80.1
# 39                    Bolivia (Plurinational State of)   2012     106.6
# 41                              Bosnia and Herzegovina   2012     108.9
# 43                                            Botswana   2012      86.5
# 45                                              Brazil   2012     118.5
# 47                                   Brunei Darussalam   2012      86.4
# 49                                            Bulgaria   2012     132.3
# 51                                        Burkina Faso   2012      91.7
# 53                                             Burundi   2012     134.1
# 55                                       Cote d'Ivoire   2012     111.3
# 57                                          Cabo Verde   2012      63.1
# 59                                            Cambodia   2012     100.6
# 61                                            Cameroon   2012      73.4
# ..                                                 ...    ...       ...
# 287                                              Spain   2012     119.8
# 289                                          Sri Lanka   2012      64.6
# 291                                              Sudan   2012      85.0
# 293                                           Suriname   2012      82.9
# 295                                          Swaziland   2012      84.9
# 297                                             Sweden   2012     110.3
# 299                                        Switzerland   2012     103.8
# 301                               Syrian Arab Republic   2012     111.8
# 303                                         Tajikistan   2012      90.5
# 305                                           Thailand   2012     102.8
# 307          The former Yugoslav republic of Macedonia   2012     146.4
# 309                                        Timor-Leste   2012     150.7
# 311                                               Togo   2012      99.8
# 313                                Trinidad and Tobago   2012     136.6
# 315                                            Tunisia   2012      73.0
# 317                                             Turkey   2012     134.2
# 319                                       Turkmenistan   2012     113.4
# 321                                             Uganda   2012     133.6
# 323                                            Ukraine   2012     118.8
# 325                               United Arab Emirates   2012      99.2
# 327  United Kingdom of Great Britain and Northern I...   2012     130.4
# 329                        United Republic of Tanzania   2012      94.9
# 331                           United States of America   2012     121.2
# 333                                            Uruguay   2012     154.3
# 335                                         Uzbekistan   2012      76.7
# 337                 Venezuela (Bolivarian Republic of)   2012      92.5
# 339                                           Viet Nam   2012     112.1
# 341                                              Yemen   2012      72.4
# 343                                             Zambia   2012     105.0
# 345                                           Zimbabwe   2012     223.0
#
#     Mortality 2 Mortality 3
# 3         110.6       142.2
# 5         105.3       142.5
# 7          78.0        83.9
# 9          86.1        97.9
# 11        109.1       166.5
# 13        175.3       277.1
# 15         90.6       135.9
# 17         99.7       152.3
# 19         88.5       145.0
# 21         88.1       131.8
# 23         65.4        80.4
# 25         79.9        94.9
# 27        117.7       179.3
# 29         79.0       182.2
# 31        102.0       167.5
# 33         57.3       114.4
# 35         82.6       104.8
# 37         79.8        80.8
# 39        109.9       106.0
# 41         80.8       146.8
# 43         70.6       110.5
# 45        100.2       142.9
# 47         80.3        94.1
# 49         99.2       175.7
# 51         92.4        95.7
# 53        142.4       130.2
# 55        100.5       123.1
# 57         62.0        68.2
# 59         92.7       111.7
# 61         73.9        75.2
# ..          ...         ...
# 287        80.8       169.3
# 289        61.4        68.8
# 291        76.2        96.0
# 293        64.8       108.7
# 295        75.7       101.1
# 297       100.5       124.9
# 299        83.9       131.1
# 301        99.0       125.4
# 303        80.0       103.0
# 305        82.6       127.8
# 307       110.1       189.5
# 309       122.3       185.4
# 311        93.9       109.0
# 313       115.2       172.8
# 315        52.9        96.6
# 317        86.9       198.5
# 319        94.6       137.9
# 321       122.3       150.0
# 323        86.2       173.1
# 325        94.1       103.6
# 327       112.5       153.9
# 329        90.9       104.4
# 331       104.2       143.6
# 333       115.9       211.5
# 335        69.7        86.2
# 337        86.8       100.8
# 339        74.2       163.4
# 341        66.0        79.7
# 343       113.5        98.8
# 345       226.6       223.5
#
# [172 rows x 5 columns]

# %%
cardio_2012.head(n=5)
# Out:
#         Country  Year Mortality Mortality 2 Mortality 3
# 3   Afghanistan  2012     511.5       520.9       498.0
# 5       Albania  2012     436.2       417.6       447.4
# 7       Algeria  2012     396.6       359.9       434.6
# 9        Angola  2012     374.6       369.8       376.4
# 11    Argentina  2012     191.7       148.4       247.8

# %%
cardio_2000.head(n=5)
# Out:
#         Country  Year Mortality Mortality 2 Mortality 3
# 4   Afghanistan  2000     542.3       554.1       523.1
# 6       Albania  2000     560.5       494.7       638.6
# 8       Algeria  2000     434.7       401.2       472.2
# 10       Angola  2000     383.4       385.2       375.2
# 12    Argentina  2000     226.6       169.1       302.8

# %%
all_foods = all_crop_dfs
print len(all_foods)
# Out:
# 89

# %%
# plot for cardio
def food_cardio_plot(food_df, cardio, ax):
    score = 1
    morts = []
    food_amts = []
    
    # for each country
    for country in food_df['AreaName'].values:
        # make sure it's in the disease df
        if not cardio[(cardio['Country'] == country)].empty:
            # find the disease data for that country
            country_data = cardio[(cardio['Country'] == country)]
            # find mortality rate
            mort = country_data.iloc[1,2]
            # append to mortality list
            morts.append(float(mort))
            # find amount of that particular food consumed in that country
            food_amt = food_df[(food_df['AreaName'] == country)].iloc[0, 9]
            # append to food_amounts
            food_amts.append(float(food_amt))
    
    # scatter the amounts against mortality rates
    ax.scatter(food_amts, morts)
    
    # reshape for LinReg to get R^2
    X = np.array(food_amts).reshape(-1, 1)
    y = np.array(morts)
    
    if (len(food_df['ItemName'].values) > 0) and (X.shape[0] > 0):
        # linreg
        regr = LinReg()
        # fit, score linreg
        regr.fit(X, y)
        score = regr.score(X,y)
        ax.set_title("R^2 = " + str(score))
    
    ax.set_xlabel(food_df['ItemName'].values[0])
    ax.set_ylabel('Cancer Disease Mortality Rate')
    
    return ax, score

# %%
# Diabetes plot works the same way except for diabetes
def food_diabetes_plot(food_df, cardio, ax):
    score = 1
    morts = []
    food_amts = []
    for country in food_df['AreaName'].values:
        if not cardio[(cardio['Country'] == country)].empty:
            country_data = cardio[(cardio['Country'] == country)]
            mort = country_data.iloc[1,2]
            morts.append(float(mort))
            food_amt = food_df[(food_df['AreaName'] == country)].iloc[0, 9]
            food_amts.append(float(food_amt))
    ax.scatter( food_amts, morts)
    X = np.array(food_amts).reshape(-1, 1)
    y = np.array(morts)
    if (len(food_df['ItemName'].values) > 0) and (X.shape[0] > 0):
        regr = LinReg()
        regr.fit(X, y)
        score = regr.score(X,y)
        ax.set_title("R^2 = " + str(score))
    
    ax.set_xlabel(food_df['ItemName'].values[0] + str('(kg/capita/yr)'))
    ax.set_ylabel('Diabetes Disease Mortality Rate')
    
    return ax, score

# %%
# Cancer works the same way except for cancer
def food_cancer_plot(food_df, cardio, ax):
    score = 1
    morts = []
    food_amts = []
    for country in food_df['AreaName'].values:
        if not cardio[(cardio['Country'] == country)].empty:
            country_data = cardio[(cardio['Country'] == country)]
            mort = country_data.iloc[1,2]
            morts.append(float(mort))
            food_amt = food_df[(food_df['AreaName'] == country)].iloc[0, 9]
            food_amts.append(float(food_amt))
    ax.scatter(food_amts, morts)
    
    X = np.array(food_amts).reshape(-1, 1)
    y = np.array(morts)
    
    if (len(food_df['ItemName'].values) > 0) and (X.shape[0] > 0):
        regr = LinReg()
        regr.fit(X, y)
        score = regr.score(X,y)
        ax.set_title("R^2 = " + str(score))
        ax.set_xlabel(food_df['ItemName'].values[0])
        ax.set_ylabel('Cancer Disease Mortality Rate')
    return ax, score

# %%
def food_disease_plot(food_df, cardio, ax,disease_name):
    score = 1
    morts = []
    food_amts = []
    for country in food_df['AreaName'].values:
        if not cardio[(cardio['Country'] == country)].empty:
            country_data = cardio[(cardio['Country'] == country)]
            mort = country_data.iloc[1,2]
            morts.append(float(mort))
            food_amt = food_df[(food_df['AreaName'] == country)].iloc[0, 9]
            food_amts.append(float(food_amt))
    ax.scatter(food_amts, morts)
    
    X = np.array(food_amts).reshape(-1, 1)
    y = np.array(morts)
    
    if (len(food_df['ItemName'].values) > 0) and (X.shape[0] > 0):
        regr = LinReg()
        regr.fit(X, y)
        score = regr.score(X,y)
        ax.set_title("R^2 = " + str(score))
        ax.set_xlabel(food_df['ItemName'].values[0])
        ax.set_ylabel(disease_name + 'Disease Mortality Rate')
    return ax, score

# %%
fig, ax = plt.subplots(18, 5, figsize=(18, 50))

#flatten list of axes
axes = [e for l in ax for e in l]

# store r2s
cardio_crop_r2 = {}

# go through and plot each one
for df, ax in zip(all_crop_dfs, axes):
    ax, r2 = food_disease_plot(df, cardio, ax, "Cardio")
    crop_name = df['ItemName'].values[0]
    cardio_crop_r2[crop_name] = r2

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(18, 5, figsize=(18, 50))

# flatten list of axes
axes = [e for l in ax for e in l]

# store r2s
diabetes_crop_r2 = {}
    
# iterate through
for df, ax in zip(all_crop_dfs, axes):
    ax, r2 = food_diabetes_plot(df, diabetes, ax)
    crop_name = df['ItemName'].values[0]
    diabetes_crop_r2[crop_name] = r2


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(18, 5, figsize=(18, 50))

# flatten list of axes
axes = [e for l in ax for e in l]

# store r2s
cancer_crop_r2 = {}

# go through
for df, ax in zip(all_crop_dfs, axes):
    ax, r2 =food_cancer_plot(df, cancer, ax)
    crop_name = df['ItemName'].values[0]
    cancer_crop_r2[crop_name] = r2

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(7, 5, figsize=(25, 35))

axes = [e for l in ax for e in l]

cardio_livestock_r2 = {}

for df, ax in zip(livestock_dfs, axes):
    ax, r2 =food_cardio_plot(df, cardio, ax)
    livestock_name = df['ItemName'].values[0]
    cardio_livestock_r2[livestock_name] = r2

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(7, 5, figsize=(25, 35))

axes = [e for l in ax for e in l]

diabetes_livestock_r2 = {}

for df, ax in zip(livestock_dfs, axes):
    ax, r2 =food_diabetes_plot(df, diabetes, ax)
    livestock_name = df['ItemName'].values[0]
    diabetes_livestock_r2[livestock_name] = r2

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(7, 5, figsize=(25, 35))

axes = [e for l in ax for e in l]

cancer_livestock_r2 = {}

for df, ax in zip(livestock_dfs, axes):
    ax, r2 =food_cancer_plot(df, cancer, ax)
    livestock_name = df['ItemName'].values[0]
    cancer_livestock_r2[livestock_name] = r2

print cancer_livestock_r2
plt.tight_layout()
plt.show()
# Out:
# {'Animal Products': 0.13782440381828331, 'Meat, Aquatic Mammals': 0.0, 'Meat Meal': 1.0, 'Aquatic Products, Other': 0.00353222275657461, 'Honey': 0.0052637428739564784, 'Whey': 0.00417475995904526, 'Butter, Ghee': 0.0094586402207729181, 'Fats, Animals, Raw': 0.0086964785852524651, 'Crustaceans': 0.0026917672873718597, 'Eggs': 0.0032996051640215018, 'Milk, Whole': 0.0045470464573785785, 'Marine Fish, Other': 0.00051488869695659467, 'Demersal Fish': 0.0047298781135477475, 'Pigmeat': 0.0061053679627908206, 'Meat': 0.0056276749097191603, 'Freshwater Fish': 0.00022119829606881411, 'Milk - Excluding Butter': 0.0018935129822559293, 'Fish, Liver Oil': 0.0072314612337650566, 'Fish, Seafood': 0.0013677082943757135, 'Meat, Other': 0.0064762318220931148, 'Cephalopods': 0.0035978159036941237, 'Mutton & Goat Meat': 0.0001075483830690338, 'Cheese': 0.015827925923861508, 'Pelagic Fish': 0.0005990698417333018, 'Offals': 0.002565371099821578, 'Bovine Meat': 0.0030885740151288528, 'Molluscs, Other': 0.0042518932555131173, 'Fish, Body Oil': 0.0059310786456356901, 'Aquatic Animals, Others': 0.003692521809931848, 'Animal fats': 0.0016317256693649804, 'Poultry Meat': 0.0045098074404874566, 'Offals, Edible': 0.0025628646945212719, 'Aquatic Plants': 0.0033703616603042441, 'Hides and skins': 1, 'Cream': 0.031645540276718509}

# %%
all_crop_dfs[0].head(n=5)
# Out:
#     ﻿Domain Code                                  Domain  AreaCode  \
# 0             CC  Food Supply - Crops Primary Equivalent       1.0
# 71            CC  Food Supply - Crops Primary Equivalent       2.0
# 130           CC  Food Supply - Crops Primary Equivalent       3.0
# 200           CC  Food Supply - Crops Primary Equivalent       4.0
# 276           CC  Food Supply - Crops Primary Equivalent       7.0
#
#         AreaName  ElementCode                          ElementName  ItemCode  \
# 0        Armenia        645.0  Food supply quantity (kg/capita/yr)    2511.0
# 71   Afghanistan        645.0  Food supply quantity (kg/capita/yr)    2511.0
# 130      Albania        645.0  Food supply quantity (kg/capita/yr)    2511.0
# 200      Algeria        645.0  Food supply quantity (kg/capita/yr)    2511.0
# 276       Angola        645.0  Food supply quantity (kg/capita/yr)    2511.0
#
#                ItemName    Year   Value Flag            FlagD
# 0    Wheat and products  2000.0  156.48   Fc  Calculated data
# 71   Wheat and products  2000.0  126.26   Fc  Calculated data
# 130  Wheat and products  2000.0  161.61   Fc  Calculated data
# 200  Wheat and products  2000.0  180.20   Fc  Calculated data
# 276  Wheat and products  2000.0   26.04   Fc  Calculated data

# %%
# dictionary of all dataframes, crop and livestock
all_dfs = {}
for df in all_crop_dfs:
    crop_name = df['ItemName'].values[0]
    all_dfs[crop_name] = df

for df in livestock_dfs:
    crop_name = df['ItemName'].values[0]
    all_dfs[crop_name] = df

# %%
print len(cancer_crop_r2)
print len(cancer_livestock_r2)
for k, v in cancer_livestock_r2.items():
    cancer_crop_r2[k] = v
print len(cancer_crop_r2)
# Out:
# 89
# 35
# 124

# %%
for k, v in diabetes_livestock_r2.items():
    diabetes_crop_r2[k] = v

# %%
print len(cardio_crop_r2)
print len(cardio_livestock_r2)
for k, v in cardio_livestock_r2.items():
    cardio_crop_r2[k] = v
print len(cardio_crop_r2)
# Out:
# 89
# 35
# 124

# %%
cancer_r2_sort = sorted(cancer_crop_r2.items(), key= lambda x: -x[1])
diabetes_r2_sort = sorted(diabetes_crop_r2.items(), key= lambda x: -x[1])
cardio_r2_sort = sorted(cardio_crop_r2.items(), key= lambda x: -x[1])

# %%
print cardio_r2_sort
# Out:
# [('Molasses', 1.0), ('Hides and skins', 1), ('Meat Meal', 1.0), ('Wheat and products', 0.17691159173120341), ('Cereals - Excluding Beer', 0.17654642887748373), ('Cottonseed Oil', 0.16233585584342747), ('Coffee and products', 0.15094498145821922), ('Oranges, Mandarines', 0.14045290297240975), ('Fruits - Excluding Wine', 0.13106405225895101), ('Stimulants', 0.13002408775163987), ('Alcoholic Beverages', 0.11919558520637275), ('Beer', 0.11153274849099726), ('Sugar & Sweeteners', 0.10093166409290155), ('Sugar, Raw Equivalent', 0.10065002834812142), ('Vegetable Oils', 0.089010886869657746), ('Soyabean Oil', 0.088158071312481212), ('Ricebran Oil', 0.085285860529225266), ('Rape and Mustard Oil', 0.083554953546264299), ('Cocoa Beans and products', 0.080178598283944802), ('Sweeteners, Other', 0.063097321078699475), ('Wine', 0.062815197565267322), ('Sugar, Refined Equiv', 0.060804073933226295), ('Sugar (Raw Equivalent)', 0.060796484725454063), ('Fruits, Other', 0.059855606502627667), ('Sugar beet', 0.0587705522464258), ('Bananas', 0.057685688912129551), ('Pineapples and products', 0.039177623144377782), ('Fish, Body Oil', 0.038797003930298279), ('Animal Products', 0.036599727827304918), ('Pepper', 0.034781245544512895), ('Infant food', 0.03171693610223536), ('Yams', 0.03018805378433087), ('Fish, Liver Oil', 0.029585948988911537), ('Olive Oil', 0.028647831276113481), ('Sunflowerseed Oil', 0.028597590294534236), ('Nuts and products', 0.028422459022769849), ('Grapes and products (excl wine)', 0.027588257800419184), ('Treenuts', 0.027429813333340488), ('Onions', 0.027043512184766746), ('Rye and products', 0.026690613684440478), ('Sunflower seed', 0.024035077547330697), ('Lemons, Limes and products', 0.023785478507202695), ('Pulses', 0.023337732543633027), ('Palmkernel Oil', 0.02328887051201578), ('Barley and products', 0.019474193591615174), ('Cheese', 0.019389474076522695), ('Grapefruit and products', 0.018699401459802423), ('Soyabeans', 0.018627522265924457), ('Cephalopods', 0.01790998368841823), ('Whey', 0.017023786211524894), ('Potatoes and products', 0.0153607535641066), ('Miscellaneous', 0.014505986125039727), ('Apples and products', 0.012415912340862367), ('Oilcrops, Other', 0.011260327880786347), ('Dates', 0.011197658738038796), ('Bovine Meat', 0.010265344391026443), ('Sugar non-centrifugal', 0.0093715217176798538), ('Sugar Crops', 0.0093143313478213363), ('Beans', 0.0089125776033324167), ('Groundnuts (in Shell Eq)', 0.0086156509725818786), ('Sugar cane', 0.0086037311252817883), ('Groundnuts (Shelled Eq)', 0.0086021626681448415), ('Maize and products', 0.008339939921861439), ('Millet and products', 0.008009884986273863), ('Meat, Other', 0.0078576744713020341), ('Poultry Meat', 0.0078351981711982654), ('Groundnut Oil', 0.0072720302794677671), ('Demersal Fish', 0.006572477964963519), ('Oats', 0.006503153373117021), ('Cereals, Other', 0.0063308652741517202), ('Oilcrops Oil, Other', 0.0063172321693797384), ('Tomatoes and products', 0.006308276185814532), ('Rice (Paddy Equivalent)', 0.005385779999942053), ('Rice (Milled Equivalent)', 0.0053857669717444212), ('Maize Germ Oil', 0.0050989784652587522), ('Meat', 0.004841486390909977), ('Animal fats', 0.0046650734171962416), ('Honey', 0.0043961872153363002), ('Aquatic Animals, Others', 0.0042405976099509912), ('Crustaceans', 0.00410013445847901), ('Fats, Animals, Raw', 0.0040488113221447408), ('Sorghum and products', 0.003902767516004602), ('Beverages, Alcoholic', 0.0037154008042193931), ('Spices, Other', 0.0037069667826254986), ('Milk - Excluding Butter', 0.0036896792004936785), ('Sesame seed', 0.0034561983146881299), ('Cream', 0.0033290043864359071), ('Vegetables', 0.0032009434943195414), ('Cassava and products', 0.0027937573578815655), ('Palm Oil', 0.0026623362304381004), ('Fish, Seafood', 0.0025354614197152792), ('Marine Fish, Other', 0.0021303471156902676), ('Spices', 0.0020839214301047182), ('Pigmeat', 0.0017626687718175216), ('Molluscs, Other', 0.0017293409922294334), ('Cloves', 0.00164 ...

# %%
print cancer_2000.shape
cancer_2000.head(n=5)
# Out:
# (172, 5)
#         Country   Year Mortality Mortality 2 Mortality 3
# 4   Afghanistan   2000     122.9       107.9       143.6
# 6       Albania   2000     137.7       109.0       169.4
# 8       Algeria   2000      75.1        77.8        72.6
# 10       Angola   2000      74.8        73.4        80.3
# 12    Argentina   2000     136.8       112.1       173.3

# %% [markdown]
# # Lin Reg for Cardio

# %%
N = 15
#x = pd.DataFrame({}) 

countries = list(cancer_2000['Country'].values)
cols = []
for name, r2 in cardio_r2_sort[:N]:
    if r2 != 1.0 and name != 'Cottonseed Oil':
        df = all_dfs[name]
        print df.shape
        cols.append(name)
        for country in countries:
            if country not in df['AreaName'].values:
                countries.remove(country)
print len(countries)

x = []
for country in countries:
    predictors = []
    for name, r2 in cardio_r2_sort[:N]:
        if r2 != 1.0 and name != 'Cottonseed Oil':
            df = all_dfs[name]
            for index, area in enumerate(df['AreaName'].values):
                if area == country and not math.isnan(df['Value'].values[index]):
                    predictors.append(df['Value'].values[index])
    x.append(predictors)

x_df = pd.DataFrame(x, columns = cols)
x_df.head(n=5)
# Out:
# (209, 12)
# (209, 12)
# (209, 12)
# (208, 12)
# (209, 12)
# (209, 12)
# (208, 12)
# (208, 12)
# (209, 12)
# (209, 12)
# (209, 12)
# 149
#    Wheat and products  Cereals - Excluding Beer  Coffee and products  \
# 0              126.26                    152.56                 0.00
# 1              161.61                    172.77                 1.28
# 2              180.20                    209.26                 3.36
# 3               26.04                     73.55                 0.11
# 4              110.99                    129.01                 1.02
#
#    Oranges, Mandarines  Fruits - Excluding Wine  Stimulants  \
# 0                 0.82                    24.74        0.94
# 1                 8.66                    70.80        1.51
# 2                12.07                    40.93        3.81
# 3                 0.00                    28.24        0.17
# 4                39.04                   109.50        9.13
#
#    Alcoholic Beverages   Beer  Sugar & Sweeteners  Sugar, Raw Equivalent  \
# 0                 0.00   0.00                3.19                   2.97
# 1                15.73  12.49               23.00                  22.80
# 2                 3.17   3.16               28.70                  28.67
# 3                15.94   8.73                9.66                   8.11
# 4                68.69  33.04               47.42                  47.29
#
#    Vegetable Oils
# 0            1.99
# 1            6.96
# 2           15.02
# 3            8.05
# 4           14.28

# %%
y = []
for country in countries:
    for index, area in enumerate(cancer_2000['Country'].values):
        if area == country:
            y.append(float(cancer_2000['Mortality'].values[index]))
            
y_df = pd.DataFrame(y, columns = ['Cancer Mortality Rate'])
y_df.head(n=5)
# Out:
#    Cancer Mortality Rate
# 0                  122.9
# 1                  137.7
# 2                   75.1
# 3                   74.8
# 4                  136.8

# %%
x_df.head(n=30)
# Out:
#     Wheat and products  Cereals - Excluding Beer  Coffee and products  \
# 0               126.26                    152.56                 0.00
# 1               161.61                    172.77                 1.28
# 2               180.20                    209.26                 3.36
# 3                26.04                     73.55                 0.11
# 4               110.99                    129.01                 1.02
# 5               156.48                    161.90                 2.62
# 6                66.25                     81.42                 2.82
# 7                80.13                    117.33                 5.31
# 8               190.92                    201.90                 0.01
# 9                46.93                     87.25                 2.64
# 10               24.14                    188.39                 0.00
# 11               68.81                    101.12                 1.45
# 12               83.78                    141.87                 0.09
# 13               99.83                    106.84                 3.51
# 14               64.17                    118.36                 2.98
# 15                7.04                     99.44                 0.05
# 16               54.29                    116.66                 2.80
# 17              100.24                    199.53                 0.41
# 18               32.16                    103.13                 0.72
# 19               43.75                     98.73                 2.87
# 20               41.89                    147.59                 2.45
# 21              136.80                    156.48                 2.18
# 22                7.99                    195.85                 0.14
# 23               35.88                    124.43                 1.85
# 24                2.18                    177.04                 0.06
# 25               13.56                     90.16                 0.37
# 26               89.47                    118.58                 4.68
# 27               10.60                     49.20                 0.98
# 28                6.07                    119.83                 0.01
# 29              111.10                    134.98                 0.59
#
#     Oranges, Mandarines  Fruits - Excluding Wine  Stimulants  \
# 0                  0.82                    24.74        0.94
# 1                  8.66                    70.80        1.51
# 2                 12.07                    40.93        3.81
# 3                  0.00                    28.24        0.17
# 4                 39.04                   109.50        9.13
# 5                  0.41                    48.11        2.93
# 6                 23.74                    90.92        5.04
# 7                  9.13                   127.06        7.98
# 8                  1.93                    58.14        0.49
# 9                112.93                   302.01        3.36
# 10                 0.27                    10.10        0.26
# 11                22.71                    86.14        0.00
# 12                 2.40                    26.25        1.20
# 13                 4.42                    72.46        3.70
# 14                88.74                   242.90        4.12
# 15                 1.99                    22.02        0.00
# 16                17.92                    97.47        4.00
# 17                 5.38                    29.47        1.56
# 18                20.88                    64.39        2.28
# 19                43.20                   109.45        6.48
# 20                13.25                    72.29        9.04
# 21                 4.28                    51.49        3.00
# 22                 0.18                     7.81        0.19
# 23                 3.33                    42.99        2.26
# 24                 4.78                    25.03        0.08
# 25                 0.03                    76.72        0.82
# 26                52.48                   126.04        6.91
# 27                 5.95                    53.05        1.10
# 28                 0.00                    10.50        0.08
# 29                 6.10                    55.07        2.52
#
#     Alcoholic Beverages    Beer  Sugar & Sweeteners  Sugar, Raw Equivalent  \
# 0                  0.00    0.00                3.19                   2.97
# 1                 15.73   12.49               23.00                  22.80
# 2                  3.17    3.16               28.70                  28.67
# 3                 15.94    8.73                9.66                   8.11
# 4                 68.69   33.04               47.42                  47.29
# 5                  6.18    2.31               24.71                  24.26
# 6                112.47   89.90               44.97                  44.38
# 7                148.63  109.90               46.51                  44.91
# 8                 19.83    8.86               10.96                  10.85
# 9                 30.20   10.07               43.62                  43.78
# 10                 0.02    0.02                6.62                   6.62
# 11                44.94   32.93               52.43                  53.96
# 12                34.97   19.36               39.17                  38.86
# 13               128.85  101.48               59.21                  58.66
# 14                33.14   27.64               44.59                  44.35
# 15                11.08    5.27                4.75                   4.80
# 16                28.25   25.51               27.78                  27.65
# 17                41.99   26.02               13.56                  13.25
# 18                52.42   24.40               23.93                  23.86
# 19                55.91   50.10               39.96                  39.83
# 20                 3.01    2.63               30.12                  32.64
# 21                69.24   51.40               28.87                  28.73
# 22               163.16    4.59                3.35                   3.35
# 23                29.41   24.36               24.89                  23.86
# 24                 5.40    3.53                8.43                   8.41
# 25                49.03   22.98                8.79                   8.55
# 26               104.28   72.52               50.56                  49.94
# 27                21.17    6.72               10.17                   6.54
# 28                 2.24    1.07                7.37                   7.25
# 29                34.17   19.48               45.75                  45.43
#
#     Vegetable Oils
# 0             1.99
# 1             6.96
# 2            15.02
# 3             8.05
# 4            14.28
# 5             3.58
# 6            19.16
# 7            18.83
# 8             2.22
# 9             3.36
# 10            6.26
# 11           11.24
# 12            8.62
# 13           22.30
# 14            4.15
# 15            5.76
# 16            3.53
# 17            6.78
# 18            5.70
# 19           16.57
# 20            6.02
# 21           13.87
# 22            4.62
# 23            6.79
# 24            1.96
# 25            7.72
# 26           25.12
# 27           10.17
# 28            3.94
# 29           10.35

# %% [markdown]
# ## Null Model Cardio

# %%
# Null Model Cardio
null_model = LinReg()
null_model.fit(x_df, [np.mean(y)]*x_df.shape[0])
null_model.score(x_df, y_df)
# Out:
# 0.0

# %%
last = -1
linreg = LinReg()
linreg.fit(x_df, y_df)
linreg.score(x_df, y_df)
# Out:
# 0.20538255210022283

# %% [markdown]
# # Lin Reg for Diabetes

# %%
N = 22
#x = pd.DataFrame({}) 

countries = list(diabetes_2000['Country'].values)
cols = []
for name, r2 in diabetes_r2_sort[:N]:
    if r2 != 1.0 and name != 'Rye and products' and name != 'Rape and Mustard Oil':
        df = all_dfs[name]
        print df.shape
        cols.append(name)
        for country in countries:
            if country not in df['AreaName'].values:
                countries.remove(country)
print len(countries)
print cols
print len(cols)

x = []
for country in countries:
    predictors = []
    for name, r2 in diabetes_r2_sort[:N]:
        if r2 != 1.0 and name != 'Rye and products' and name != 'Rape and Mustard Oil':
            df = all_dfs[name]
            for index, area in enumerate(df['AreaName'].values):
                #if area == country and not math.isnan(df['Value'].values[index]):
                if area == country:
                    predictors.append(df['Value'].values[index])
                    #print name
                    break
    x.append(predictors)
    #print 'end'

x_df = pd.DataFrame(x, columns = cols)
x_df.head(n=5)
# Out:
# (209, 12)
# (759, 12)
# (209, 12)
# (205, 12)
# (209, 12)
# (209, 12)
# (205, 12)
# (208, 12)
# (207, 12)
# (208, 12)
# (207, 12)
# (206, 12)
# (202, 12)
# (206, 12)
# (209, 12)
# (208, 12)
# (209, 12)
# 139
# ['Potatoes and products', 'Animal Products', 'Apples and products', 'Wine', 'Coffee and products', 'Stimulants', 'Pulses, Other and products', 'Beer', 'Spices, Other', 'Pulses', 'Oilcrops', 'Grapes and products (excl wine)', 'Coconuts - Incl Copra', 'Beverages, Alcoholic', 'Vegetables', 'Alcoholic Beverages', 'Vegetables, Other']
# 17
#    Potatoes and products  Animal Products  Apples and products   Wine  \
# 0                  10.63            275.0                 0.40   0.00
# 1                  29.18            674.0                10.94   2.37
# 2                  37.07            277.0                 2.89   0.01
# 3                  48.21           1014.0                14.21  33.90
# 4                  63.78            347.0                 3.97   1.29
#
#    Coffee and products  Stimulants  Pulses, Other and products   Beer  \
# 0                 0.00        0.94                        1.05   0.00
# 1                 1.28        1.51                        0.17  12.49
# 2                 3.36        3.81                        3.87   3.16
# 3                 1.02        9.13                        0.68  33.04
# 4                 2.62        2.93                        0.00   2.31
#
#    Spices, Other  Pulses  Oilcrops  Grapes and products (excl wine)  \
# 0           0.00    1.05      0.58                             9.13
# 1           0.01    5.14      7.87                            22.15
# 2           0.10    5.45      0.73                             4.59
# 3           0.13    1.03      1.44                             1.05
# 4           0.00    0.00      0.33                            12.39
#
#    Coconuts - Incl Copra  Beverages, Alcoholic  Vegetables  \
# 0                   0.00                  0.00       29.34
# 1                   0.00                  0.93      156.73
# 2                   0.00                  0.00       75.82
# 3                   0.31                  1.77       71.81
# 4                   0.00                  2.62      120.61
#
#    Alcoholic Beverages  Vegetables, Other
# 0                 0.00              29.34
# 1                15.73             102.24
# 2                 3.17              42.43
# 3                68.69              39.70
# 4                 6.18              71.41

# %%
y = []
for country in countries:
    for index, area in enumerate(diabetes_2000['Country'].values):
        if area == country:
            y.append(float(diabetes_2000['Mortality'].values[index]))
            
y_df = pd.DataFrame(y, columns = ['Diabetes Mortality Rate'])
y_df.head(n=5)
# Out:
#    Diabetes Mortality Rate
# 0                     34.0
# 1                      8.3
# 2                     67.2
# 3                     19.9
# 4                     32.2

# %%
x_df.head(n=20)
# Out:
#     Potatoes and products  Animal Products  Apples and products   Wine  \
# 0                   10.63            275.0                 0.40   0.00
# 1                   29.18            674.0                10.94   2.37
# 2                   37.07            277.0                 2.89   0.01
# 3                   48.21           1014.0                14.21  33.90
# 4                   63.78            347.0                 3.97   1.29
# 5                   52.54            977.0                14.71  20.26
# 6                   62.13           1251.0                56.83  31.17
# 7                   46.99            314.0                15.35   0.57
# 8                   27.83            881.0                35.47   5.66
# 9                   18.08             74.0                 0.04   0.00
# 10                  40.01            656.0                19.42   3.82
# 11                 174.32            790.0                11.03   2.53
# 12                 126.42           1173.0                31.32  25.77
# 13                  15.22            577.0                 2.54   0.72
# 14                   0.07             94.0                 0.73   0.55
# 15                  49.00            331.0                 2.24   0.33
# 16                  69.67            399.0                 7.17   1.41
# 17                  12.81            357.0                 9.81   1.68
# 18                  12.76            643.0                 5.62   1.82
# 19                   8.19            537.0                 5.34   0.15
#
#     Coffee and products  Stimulants  Pulses, Other and products    Beer  \
# 0                  0.00        0.94                        1.05    0.00
# 1                  1.28        1.51                        0.17   12.49
# 2                  3.36        3.81                        3.87    3.16
# 3                  1.02        9.13                        0.68   33.04
# 4                  2.62        2.93                        0.00    2.31
# 5                  2.82        5.04                        0.55   89.90
# 6                  5.31        7.98                        0.12  109.90
# 7                  0.01        0.49                        0.00    8.86
# 8                  2.64        3.36                        0.96   10.07
# 9                  0.00        0.26                        2.67    0.02
# 10                 1.45        0.00                        3.33   32.93
# 11                 0.09        1.20                        0.00   19.36
# 12                 3.51        3.70                        0.38  101.48
# 13                 2.98        4.12                        0.25   27.64
# 14                 0.05        0.00                        2.16    5.27
# 15                 2.80        4.00                        1.49   25.51
# 16                 0.41        1.56                        0.49   26.02
# 17                 0.72        2.28                        9.46   24.40
# 18                 2.87        6.48                        0.13   50.10
# 19                 2.45        9.04                        1.02    2.63
#
#     Spices, Other  Pulses  Oilcrops  Grapes and products (excl wine)  \
# 0            0.00    1.05      0.58                             9.13
# 1            0.01    5.14      7.87                            22.15
# 2            0.10    5.45      0.73                             4.59
# 3            0.13    1.03      1.44                             1.05
# 4            0.00    0.00      0.33                            12.39
# 5            0.06    1.19      4.36                            11.01
# 6            0.29    0.87      3.62                             6.63
# 7            0.03    0.00      0.00                             7.89
# 8            0.88    0.00      0.00                             7.96
# 9            0.86    4.00      0.49                             0.09
# 10           0.81    7.49      7.49                             6.22
# 11           0.10    0.00      0.40                             0.25
# 12           0.40    2.43      3.41                             3.24
# 13           0.08   10.48      6.60                             1.20
# 14           0.00   10.51      9.50                             0.18
# 15           0.05    2.35      1.06                             3.11
# 16           0.23    2.87      0.00                             2.10
# 17           0.73   12.54      0.57                             0.61
# 18           0.05   16.74     13.43                             3.01
# 19           2.11    0.00      6.02                             2.10
#
#     Coconuts - Incl Copra  Beverages, Alcoholic  Vegetables  \
# 0                    0.00                  0.00       29.34
# 1                    0.00                  0.93      156.73
# 2                    0.00                  0.00       75.82
# 3                    0.31                  1.77       71.81
# 4                    0.00                  2.62      120.61
# 5                    2.27                  2.05       97.93
# 6                    0.73                  7.25       81.92
# 7                    0.00                 10.38       99.41
# 8                    1.34                 12.67      130.87
# 9                    0.03                  0.01       12.55
# 10                   7.47                  7.34       63.67
# 11                   0.03                 10.66       94.68
# 12                   1.71                  1.56      119.40
# 13                   3.41                  4.42       57.74
# 14                   0.29                  0.42       52.53
# 15                   0.14                  2.21       55.09
# 16                   0.05                 14.48      125.98
# 17                   0.21                  0.82       46.15
# 18                  10.22                  3.99       37.64
# 19                   3.22                  0.26       72.29
#
#     Alcoholic Beverages  Vegetables, Other
# 0                  0.00              29.34
# 1                 15.73             102.24
# 2                  3.17              42.43
# 3                 68.69              39.70
# 4                  6.18              71.41
# 5                112.47              64.03
# 6                148.63              63.96
# 7                 19.83              47.05
# 8                 30.20             106.12
# 9                  0.02              10.69
# 10                44.94              52.72
# 11                34.97              74.88
# 12               128.85              96.05
# 13                33.14              42.62
# 14                11.08              27.13
# 15                28.25              40.10
# 16                41.99             109.70
# 17                52.42              23.78
# 18                55.91              16.42
# 19                 3.01              64.61

# %% [markdown]
# ## Null Model Diabetes

# %%
# Null Model Diabetes
null_model = LinReg()
null_model.fit(x_df, [np.mean(y)]*x_df.shape[0])
null_model.score(x_df, y_df)
# Out:
# 0.0

# %%
last = -1
linreg = LinReg()
#linreg.fit(x_df.iloc[:, :last], y_df)
#linreg.score(x_df.iloc[:, :last], y_df)
linreg.fit(x_df, y_df)
linreg.score(x_df, y_df)
# Out:
# 0.40876401184532102

# %% [markdown]
# # Lin Reg for Cancer

# %%
N = 20
#x = pd.DataFrame({}) 

countries = list(cancer_2000['Country'].values)
#print countries
#print cancer_r2_sort[:20]
cols = []
for name, r2 in cancer_r2_sort[:N]:
    if r2 != 1.0 and name != 'Palm Oil' and name != 'Millet and products' and name != 'Rye and products':
        df = all_dfs[name]
        print df.shape
        cols.append(name)
        for country in countries:
            if country not in df['AreaName'].values:
                countries.remove(country)
    else:
        print 'r^2 was 1'
print len(countries)
print cols
print len(cols)

x = []
for country in countries:
    predictors = []
    for name, r2 in cancer_r2_sort[:N]:
        if r2 != 1.0 and name != 'Palm Oil' and name != 'Millet and products' and name != 'Rye and products':
            df = all_dfs[name]
            for index, area in enumerate(df['AreaName'].values):
                #if area == country and not math.isnan(df['Value'].values[index]):
                if area == country:
                    predictors.append(df['Value'].values[index])
                    #print name
                    break
    x.append(predictors)
    #print 'end'

x_df = pd.DataFrame(x, columns = cols)
x_df.head(n=5)
# Out:
# r^2 was 1
# r^2 was 1
# r^2 was 1
# (209, 12)
# (759, 12)
# (209, 12)
# r^2 was 1
# (206, 12)
# (208, 12)
# (205, 12)
# (208, 12)
# (205, 12)
# (209, 12)
# (209, 12)
# (209, 12)
# (209, 12)
# (194, 12)
# r^2 was 1
# r^2 was 1
# (209, 12)
# 135
# ['Potatoes and products', 'Animal Products', 'Apples and products', 'Beverages, Alcoholic', 'Alcoholic Beverages', 'Pulses, Other and products', 'Beer', 'Wine', 'Cocoa Beans and products', 'Stimulants', 'Vegetables, Other', 'Coffee and products', 'Sunflowerseed Oil', 'Rice (Paddy Equivalent)']
# 14
#    Potatoes and products  Animal Products  Apples and products  \
# 0                  10.63            275.0                 0.40
# 1                  29.18            674.0                10.94
# 2                  37.07            277.0                 2.89
# 3                  48.21           1014.0                14.21
# 4                  63.78            347.0                 3.97
#
#    Beverages, Alcoholic  Alcoholic Beverages  Pulses, Other and products  \
# 0                  0.00                 0.00                        1.05
# 1                  0.93                15.73                        0.17
# 2                  0.00                 3.17                        3.87
# 3                  1.77                68.69                        0.68
# 4                  2.62                 6.18                        0.00
#
#     Beer   Wine  Cocoa Beans and products  Stimulants  Vegetables, Other  \
# 0   0.00   0.00                      0.00        0.94              29.34
# 1  12.49   2.37                      0.42        1.51             102.24
# 2   3.16   0.01                      0.26        3.81              42.43
# 3  33.04  33.90                      0.75        9.13              39.70
# 4   2.31   1.29                      0.49        2.93              71.41
#
#    Coffee and products  Sunflowerseed Oil  Rice (Paddy Equivalent)
# 0                 0.00               0.23                    27.07
# 1                 1.28               4.25                     8.19
# 2                 3.36               9.30                     2.55
# 3                 1.02              10.67                     7.91
# 4                 2.62               1.25                     4.64

# %%
y = []
for country in countries:
    for index, area in enumerate(cancer_2000['Country'].values):
        if area == country:
            y.append(float(cancer_2000['Mortality'].values[index]))
            
y_df = pd.DataFrame(y, columns = ['Cancer Mortality Rate'])
y_df.head(n=5)
# Out:
#    Cancer Mortality Rate
# 0                  122.9
# 1                  137.7
# 2                   75.1
# 3                  136.8
# 4                  209.0

# %%
x_df.head(n=20)
# Out:
#     Potatoes and products  Animal Products  Apples and products  \
# 0                   10.63            275.0                 0.40
# 1                   29.18            674.0                10.94
# 2                   37.07            277.0                 2.89
# 3                   48.21           1014.0                14.21
# 4                   63.78            347.0                 3.97
# 5                   52.54            977.0                14.71
# 6                   62.13           1251.0                56.83
# 7                   46.99            314.0                15.35
# 8                   27.83            881.0                35.47
# 9                   18.08             74.0                 0.04
# 10                  40.01            656.0                19.42
# 11                 174.32            790.0                11.03
# 12                 126.42           1173.0                31.32
# 13                  15.22            577.0                 2.54
# 14                   0.07             94.0                 0.73
# 15                  49.00            331.0                 2.24
# 16                  69.67            399.0                 7.17
# 17                  12.81            357.0                 9.81
# 18                  12.76            643.0                 5.62
# 19                   8.19            537.0                 5.34
#
#     Beverages, Alcoholic  Alcoholic Beverages  Pulses, Other and products  \
# 0                   0.00                 0.00                        1.05
# 1                   0.93                15.73                        0.17
# 2                   0.00                 3.17                        3.87
# 3                   1.77                68.69                        0.68
# 4                   2.62                 6.18                        0.00
# 5                   2.05               112.47                        0.55
# 6                   7.25               148.63                        0.12
# 7                  10.38                19.83                        0.00
# 8                  12.67                30.20                        0.96
# 9                   0.01                 0.02                        2.67
# 10                  7.34                44.94                        3.33
# 11                 10.66                34.97                        0.00
# 12                  1.56               128.85                        0.38
# 13                  4.42                33.14                        0.25
# 14                  0.42                11.08                        2.16
# 15                  2.21                28.25                        1.49
# 16                 14.48                41.99                        0.49
# 17                  0.82                52.42                        9.46
# 18                  3.99                55.91                        0.13
# 19                  0.26                 3.01                        1.02
#
#       Beer   Wine  Cocoa Beans and products  Stimulants  Vegetables, Other  \
# 0     0.00   0.00                      0.00        0.94              29.34
# 1    12.49   2.37                      0.42        1.51             102.24
# 2     3.16   0.01                      0.26        3.81              42.43
# 3    33.04  33.90                      0.75        9.13              39.70
# 4     2.31   1.29                      0.49        2.93              71.41
# 5    89.90  20.26                      1.45        5.04              64.03
# 6   109.90  31.17                      2.37        7.98              63.96
# 7     8.86   0.57                      0.08        0.49              47.05
# 8    10.07   5.66                      0.67        3.36             106.12
# 9     0.02   0.00                      0.00        0.26              10.69
# 10   32.93   3.82                      0.79        0.00              52.72
# 11   19.36   2.53                      0.86        1.20              74.88
# 12  101.48  25.77                      0.08        3.70              96.05
# 13   27.64   0.72                      0.99        4.12              42.62
# 14    5.27   0.55                      0.02        0.00              27.13
# 15   25.51   0.33                      0.89        4.00              40.10
# 16   26.02   1.41                      1.14        1.56             109.70
# 17   24.40   1.68                      0.42        2.28              23.78
# 18   50.10   1.82                      0.82        6.48              16.42
# 19    2.63   0.15                      1.87        9.04              64.61
#
#     Coffee and products  Sunflowerseed Oil  Rice (Paddy Equivalent)
# 0                  0.00               0.23                    27.07
# 1                  1.28               4.25                     8.19
# 2                  3.36               9.30                     2.55
# 3                  1.02              10.67                     7.91
# 4                  2.62               1.25                     4.64
# 5                  2.82               2.85                    13.13
# 6                  5.31               4.86                     5.32
# 7                  0.01               0.71                     5.06
# 8                  2.64               0.10                    32.79
# 9                  0.00               0.00                   245.78
# 10                 1.45               0.03                    21.66
# 11                 0.09               5.51                     2.70
# 12                 3.51               2.19                     6.11
# 13                 2.98               1.53                    45.88
# 14                 0.05               0.00                    14.18
# 15                 2.80               1.32                    32.48
# 16                 0.41               5.82                     1.00
# 17                 0.72               3.32                     8.64
# 18                 2.87               0.55                    57.33
# 19                 2.45               0.90                   112.45

# %% [markdown]
# ## Null Model Cancer

# %%
# Null Model Cancer
null_model = LinReg()
null_model.fit(x_df, [np.mean(y)]*x_df.shape[0])
null_model.score(x_df, y_df)
# Out:
# 0.0

# %%
last = -1
linreg = LinReg()
linreg.fit(x_df, y_df)
linreg.score(x_df, y_df)
# Out:
# 0.31225202575257005
